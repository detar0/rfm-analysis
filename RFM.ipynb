# %% [markdown]
# Importing necessary libraries for work

# %%
import pandas as pd
import numpy as np
import zipfile
import sqlite3
from datetime import datetime

# %% [markdown]
# # Unzipping the file
# Reading the zipfile with `zipfile` and its module `ZipFile`, Extracting everything to `content` folder

# %%
with zipfile.ZipFile("/content/online_retail.csv.zip") as zipf:
  zipf.extractall("/content")

# %% [markdown]
# # CSV Reading
# Reading the csv using `pandas` module `read_csv`, displaying the first 5 rows of the read dataset with `df.head()`, clearing the `CustomerID` subset using `dropna`. Converting dates to datetime using `pd.to_datetime`

# %%
df=pd.read_csv("/content/online_retail.csv")
print(df.head())
df=df.dropna(subset="CustomerID")
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime("%Y-%m-%d")
print(df.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01       2.55     17850.0  United Kingdom
# 1  2010-12-01       3.39     17850.0  United Kingdom
# 2  2010-12-01       2.75     17850.0  United Kingdom
# 3  2010-12-01       3.39     17850.0  United Kingdom
# 4  2010-12-01       3.39     17850.0  United Kingdom

# %% [markdown]
# # Connecting to SQL
# Connecting to an temporary sqlite3 server using early-imported module sqlite3. Converting the dataframe to a SQL query so I can work with it using SQL

# %%
conn=sqlite3.connect(":memory:")
df.to_sql("Table", conn, index=True,if_exists="replace")
# Out:
# 406829

# %% [markdown]
# # Working with the query
# Selecting CustomerID, calculating Recency using `JULIANDAY`, Frequency with no duplicates and Monetary multiplying Quantity and Price

# %%
query="""
SELECT
    CustomerID,
    JULIANDAY((SELECT MAX(InvoiceDate) FROM "Table")) - JULIANDAY(MAX(InvoiceDate)) AS Recency,
    COUNT(DISTINCT InvoiceNo) AS Frequency,
    SUM(Quantity*UnitPrice) AS Monetary
FROM "Table"
WHERE CustomerID IS NOT NULL
GROUP BY CustomerID;
"""
data=pd.read_sql_query(query,conn)
print(data.head())
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0     12346.0    325.0          2      0.00
# 1     12347.0      2.0          7   4310.00
# 2     12348.0     75.0          4   1797.24
# 3     12349.0     18.0          1   1757.55
# 4     12350.0    310.0          1    334.40

# %% [markdown]
# # Plotly work
# Creating 3 Histograms with plotly: Recency, Frequency, and Monetary.

# %%
import plotly.express as px
import plotly.graph_objects as go

hist_fig = px.histogram(
    data["Recency"],
    x="Recency",
    nbins=30,
    title="Recency Distribution",
    labels={"Recency": "Buying Recency"}
)
hist_fig1 = px.histogram(
    data["Frequency"],
    x="Frequency",
    nbins=30,
    title="Frequency Distribution",
    labels={"Frequency": "Buying Frequency"}
)
hist_fig2 = px.histogram(
    data["Monetary"],
    x="Monetary",
    nbins=30,
    title="Monetary Distribution",
    labels={"Monetary": "Buying Monetary"}
)
hist_fig.show()
hist_fig1.show()
hist_fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="02526fb0-9540-4b49-81ff-ddfaa44e75c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02526fb0-9540-4b49-81ff-ddfaa44e75c4")) {                    Plotly.newPlot(                        "02526fb0-9540-4b49-81ff-ddfaa44e75c4",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Buying Recency=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"x":[325.0,2.0,75.0,18.0,310.0,36.0,204.0,232.0,214.0,22.0,33.0,1.0,7.0,52.0,287.0,3.0,109.0,7.0,291.0,4.0,51.0,44.0,71.0,311.0,25.0,2.0,315.0,129.0,81.0,21.0,4.0,184.0,28.0,337.0,15.0,79.0,21.0,72.0,63.0,15.0,35.0,45.0,119.0,303.0,323.0,49.0,148.0,22.0,49.0,32.0,78.0,301.0,74.0,66.0,217.0,24.0,3.0,112.0,63.0,15.0,95.0,0.0,162.0,78.0,194.0,11.0,25.0,9.0,43.0,35.0,42.0,0.0,84.0,79.0,99.0,1.0,14.0,366.0,3.0,21.0,22.0,57.0,243.0,44.0,22.0,156.0,10.0,16.0,134.0,53.0,73.0,44.0,58.0,71.0,94.0,2.0,46.0,10.0,7.0,143.0,2.0,30.0,29.0,17.0,53.0,1.0,22.0,3.0,3.0,28.0,22.0,17.0,32.0,9.0,336.0,5.0,38.0,63.0,165.0,9.0,81.0,21.0,23.0,315.0,95.0,337.0,18.0,301.0,232.0,134.0,26.0,284.0,142.0,66.0,84.0,267.0,353.0,77.0,28.0,0.0,63.0,79.0,142.0,39.0,1.0,9.0,0.0,81.0,9.0,59.0,14.0,30.0,130.0,91.0,7.0,29.0,22.0,19.0,29.0,29.0,75.0,46.0,197.0,166.0,79.0,357.0,38.0,8.0,50.0,16.0,1.0,310.0,5.0,302.0,8.0,261.0,281.0,72.0,22.0,2.0,39.0,8.0,227.0,315.0,35.0,35.0,21.0,73.0,246.0,39.0,238.0,2.0,3.0,234.0,17.0,7.0,39.0,28.0,190.0,317.0,92.0,108.0,37.0,51.0,19.0,9.0,29.0,28.0,189.0,58.0,21.0,79.0,365.0,58.0,78.0,22.0,52.0,57.0,31.0,277.0,2.0,85.0,29.0,21.0,16.0,14.0,1.0,232.0,276.0,106.0,211.0,23.0,10.0,4.0,9.0,57.0,58.0,89.0,67.0,33.0,238.0,23.0,115.0,25.0,128.0,129.0,33.0,4.0,22.0,154.0,107.0,3.0,334.0,322.0,148.0,10.0,17.0,11.0,18.0,29.0,11.0,0.0,8.0,324.0,359.0,58.0,7.0,150.0,10.0,329.0,5.0,11.0,24.0,42.0,52.0,0.0,14.0,3.0,4.0,7.0,28.0,371.0,113.0,25.0,205.0,28.0,120.0,70.0,7.0,21.0,7.0,79.0,19.0,64.0,7.0,15.0,291.0,29.0,3.0,96.0,22.0,0.0,9.0,106.0,3.0,151.0,71.0,5.0,2.0,31.0,85.0,3.0,5.0,371.0,28.0,10.0,71.0,113.0,23.0,179.0,234.0,352.0,315.0,332.0,372.0,78.0,63.0,134.0,51.0,2.0,0.0,3.0,128.0,81.0,3.0,235.0,249.0,86.0,15.0,116.0,52.0,7.0,138.0,316.0,3.0,238.0,210.0,59.0,17.0,19.0,21.0,21.0,4.0,2.0,9.0,2.0,9.0,65.0,192.0,373.0,256.0,334.0,53.0,18.0,360.0,10.0,183.0,36.0,168.0,260.0,44.0,101.0,147.0,95.0,281.0,178.0,3.0,214.0,70.0,74.0,59.0,2.0,5.0,2.0,322.0,37.0,262.0,32.0,145.0,282.0,59.0,173.0,33.0,2.0,143.0,4.0,70.0,65.0,29.0,267.0,22.0,31.0,96.0,290.0,107.0,78.0,372.0,7.0,210.0,52.0,138.0,26.0,283.0,26.0,185.0,366.0,84.0,326.0,282.0,143.0,57.0,3.0,18.0,44.0,275.0,9.0,24.0,88.0,63.0,67.0,214.0,24.0,185.0,30.0,42.0,204.0,8.0,264.0,18.0,11.0,58.0,39.0,23.0,2.0,4.0,148.0,138.0,128.0,8.0,17.0,3.0,161.0,64.0,88.0,4.0,35.0,122.0,78.0,21.0,24.0,2.0,17.0,15.0,25.0,64.0,46.0,131.0,301.0,35.0,288.0,143.0,16.0,30.0,2.0,8.0,5.0,9.0,1.0,306.0,4.0,7.0,8.0,89.0,9.0,3.0,112.0,7.0,3.0,197.0,211.0,156.0,155.0,29.0,239.0,18.0,0.0,73.0,292.0,3.0,31.0,23.0,23.0,4.0,77.0,22.0,196.0,106.0,4.0,318.0,105.0,11.0,173.0,56.0,323.0,372.0,9.0,1.0,2.0,53.0,73.0,7.0,16.0,4.0,64.0,1.0,113.0,22.0,30.0,11.0,38.0,357.0,54.0,57.0,138.0,80.0,8.0,253.0,291.0,99.0,30.0,31.0,14.0,64.0,9.0,212.0,64.0,24.0,249.0,253.0,72.0,191.0,12.0,373.0,24.0,82.0,10.0,0.0,192.0,266.0,129.0,1.0,1.0,4.0,179.0,1.0,126.0,4.0,157.0,2.0,8.0,21.0,70.0,267.0,21.0,70.0,32.0,1.0,99.0,234.0,1.0,39.0,3.0,128.0,44.0,372.0,2.0,31.0,0.0,8.0,117.0,21.0,19.0,238.0,269.0,94.0,89.0,4.0,77.0,94.0,23.0,261.0,273.0,72.0,196.0,50.0,10.0,22.0,16.0,108.0,84.0,19.0,332.0,39.0,26.0,10.0,29.0,14.0,20 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="946c7d1c-fa9a-4bd2-abfd-1df9821127cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("946c7d1c-fa9a-4bd2-abfd-1df9821127cf")) {                    Plotly.newPlot(                        "946c7d1c-fa9a-4bd2-abfd-1df9821127cf",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Buying Frequency=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"x":[2,7,4,1,1,11,1,1,1,3,1,2,6,3,1,13,2,4,3,1,4,2,3,1,1,3,2,1,3,5,6,6,3,2,6,1,1,4,2,15,2,1,4,1,1,2,1,3,5,9,7,3,3,5,3,26,12,1,1,5,3,9,2,1,1,5,12,4,1,18,5,7,4,2,1,19,2,1,1,5,1,1,1,1,4,2,6,3,1,2,6,4,12,2,2,4,7,8,3,3,49,13,9,30,1,20,9,1,3,4,11,13,8,3,1,10,1,2,3,13,1,3,13,2,5,1,4,1,1,4,2,1,2,2,2,1,1,2,6,5,1,6,1,2,13,8,3,3,8,5,1,1,1,2,5,1,5,19,3,2,2,3,2,1,1,1,2,14,2,5,2,3,4,1,7,1,2,2,11,35,2,3,1,1,6,4,4,3,1,1,2,18,18,4,2,1,1,2,3,1,2,3,11,2,5,9,7,11,6,1,1,2,1,2,3,7,1,2,6,1,4,5,1,1,13,3,23,1,1,2,3,13,7,4,2,1,5,2,10,1,1,3,1,3,6,1,5,2,13,1,4,1,1,2,2,5,8,5,1,1,1,12,10,2,1,1,6,4,6,1,2,7,6,13,9,4,27,31,20,7,6,1,1,2,1,6,6,2,4,5,6,2,1,2,10,14,1,16,26,4,17,1,5,1,2,3,1,3,29,7,6,5,4,1,7,9,4,1,14,1,1,1,2,1,1,2,1,2,10,11,224,8,1,1,11,5,4,1,19,2,3,2,2,1,7,1,1,1,6,7,12,5,6,8,2,2,3,1,1,1,1,2,2,1,3,3,2,3,2,3,1,1,2,2,1,2,4,1,3,5,1,8,3,6,3,7,1,2,1,1,4,1,2,16,6,26,2,9,2,4,1,2,1,2,9,5,1,8,2,2,1,3,1,10,6,1,2,2,1,2,2,12,3,4,1,2,4,1,4,3,4,1,3,1,3,2,36,1,2,5,4,8,8,5,5,2,5,1,8,1,50,1,1,5,2,5,2,4,20,4,8,5,4,1,8,4,3,1,2,1,11,8,10,3,8,5,1,14,1,12,2,9,1,1,4,1,4,89,1,1,1,12,2,2,1,3,3,1,19,3,2,4,5,2,7,3,3,15,1,3,22,3,1,2,1,11,15,16,5,3,1,29,12,2,8,6,3,3,2,3,1,2,3,3,3,2,2,1,1,2,18,5,2,28,1,4,3,1,1,1,1,4,1,3,1,2,27,1,1,1,4,43,5,1,21,10,2,3,118,18,2,6,13,16,1,14,41,1,1,27,1,6,2,5,1,5,8,40,14,2,8,7,1,2,2,3,10,1,1,4,1,2,7,1,11,9,6,8,3,6,1,1,5,1,4,17,4,2,1,1,4,5,4,5,1,1,5,2,2,4,5,2,1,5,2,3,1,1,11,1,9,12,1,5,1,1,2,2,1,1,4,8,39,4,4,2,7,11,1,3,4,6,1,5,1,4,2,2,3,8,1,1,1,1,15,7,2,2,3,5,1,4,3,1,1,1,7,4,2,3,2,3,1,3,1,1,2,1,35,5,19,27,15,17,1,2,2,1,2,4,1,2,3,6,2,2,4,1,2,2,2,1,4,1,1,2,4,1,1,10,1,4,5,6,2,5,4,5,9,3,36,6,2,1,5,12,1,9,1,4,3,1,3,1,3,1,7,1,2,3,2,1,1,1,3,1,2,1,1,1,1,1,2,5,2,2,3,1,2,2,2,1,3,2,3,3,7,1,9,1,3,3,1,1,10,1,4,6,1,2,1,2,3,81,7,1,3,2,2,23,1,4,3,2,3,12,3,1,4,4,2,2,9,1,7,1,1,4,10,1,6,6,2,2,4,7,22,2,3,2,1,2,2,41,2,4,3,1,4,4,8,3,8,1,1,1,1,3,3,17,4,10,3,2,1,6,3,3,7,4,2,3,1,1,8,3,4,1,7,5,1,1,1,4,3,5,1,2,8,3,1,6,5,2,8,2,2,1,3,43,7,7,4,2,3,2,8,1,16,4,2,4,1,1,3,2,5,2,2,1,2,1,12,1,2,5,20,5,2,1,1,1,3,13,2,7,3,4,6,1,2,2,33,1,2,1,1,3,1,9,4,4,2,3,1,1,7,1,7,11,11,12,6,5,1,6,3,1,1,1,3,5,1,5,2,7,2,3,6,2,2,2,7,3,7,1,3,1,29,2,1,6,2,2,1,5,4,1,2,7,1,1,1,5,2,60,15,1,1,10,1,10,3,1,2,1,17,1,2,1,8,1,7,2,5,4,1,4,1,11,2,2,6,2,2,1,8,3,1,1,1,4,14,8,2,2,1,5,5,1,6,1,2,10,15,7,2,2,2,2,3,3,52,16,5,3,1,41,1,2,1,6,11,1,2,1,3,2,63,2,1,1,6,1,7,2,1,1,5,1,4,4,3,5,3,5,4,2,3,2,2,2,5,2,3,1,1,6,2,1,4,2,4,1,9,1,1,4,3,2,2,3,2,29,5,1,1,6,10,2,4,1,3,2,4,10,14,4,1,5,1,1,1,13,22,6,9,6,2,1,1,2,1,14,4,1,5,5,1,1,2,3,5,2,5,9,3,2,2,3,1,1,11,6,1,1,4,3,2,3,1,2,1,2,1,1,4,4,7,3,1,1,6,5,3,3,7,3,2,5,1,3,2,2,4,1,20,11,2,1,1,7,1,2,1,1,5,13,6,16,1,9,2,1,7,1,12,6,6,15,2,4,2,7,5,3,3,1,3,1,1,5,4,2,3,1,2,2,1,2,8,23,18,4,5,1,2,4,1,15,1,4,4,1,7,2,6,2,26,1,2,1,1,29,18,1,20,12,7,1,2,1,9,2,3,1,5,6,1,1,4,1,9,19,2,14,1,1,17,1,34,1,12,1,6,8,2,2,8,3,2,13,5,12,8,2,5,1,1,6,1,3,4,3,2,5,1,12,5,15,2,1,3,6,1,1,5,6,3,1,3,2,3,2,1,66,3,1,14,3,2,4,2,1,4,1,4,1,7,5,5,7,2,31,1,1,10,24,14,2,32,3,1,7,1,9,1,4,2,1,7,7,13,1,1,7,7,4,24,1,1,2,10,1,4,4,7,15,5,5,8,5,4,6,2,1,1,13,2,1,2,14,5,3,1,1,3,5,3,6,10,1,2,8,3,2,7,1,1,2,4,5,4,1,15,3,4,5,4,2,6,6,12,14,4,2,6,45,18,1,2,2,5,3,6,10,2,6,1,7,1,3,5,4,2,1,14,2,3,2,9,2,4,4,4,1, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="281460a8-1452-4b35-8367-674941ec1317" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("281460a8-1452-4b35-8367-674941ec1317")) {                    Plotly.newPlot(                        "281460a8-1452-4b35-8367-674941ec1317",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Buying monetary=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0.0,4309.999999999997,1797.24,1757.55,334.40000000000003,1545.4100000000005,89.0,1079.4,459.4,2811.4300000000007,6207.669999999996,1168.06,6245.530000000006,2662.0600000000004,189.89999999999998,5154.580000000002,552.0,1313.1000000000001,320.69,168.9,3545.689999999998,1887.9600000000003,1298.0400000000002,364.6,742.93,455.42000000000013,1628.1199999999997,4008.6200000000013,850.2899999999996,2720.56,1803.9600000000005,1839.3099999999997,566.16,401.90000000000003,2780.6600000000003,549.8399999999999,460.88999999999993,1582.6000000000004,1272.48,2998.279999999999,2409.9000000000005,1635.6599999999999,1108.65,84.3,225.6,409.7,1710.3900000000006,3280.7500000000014,1708.1199999999997,2842.57,11056.930000000004,681.0799999999999,1226.8799999999999,694.15,562.41,123725.44999999987,3578.8,668.5799999999997,600.3900000000001,806.2700000000002,803.5599999999998,1849.1100000000001,1760.9599999999998,777.1999999999999,582.7299999999999,708.3700000000001,7877.200000000004,3750.400000000001,256.4,6416.389999999999,5059.3200000000015,13375.869999999992,765.1899999999999,7829.889999999998,509.01000000000005,4896.659999999998,2906.8500000000004,173.55,172.06,5005.46,133.4,1002.3099999999998,476.49,449.4500000000001,4067.2900000000013,197.88,8933.519999999999,428.57000000000005,707.0899999999999,-5.684341886080802e-14,2466.859999999997,3153.889999999998,1917.78,947.4000000000001,826.8800000000001,1124.0099999999998,1303.6299999999997,1212.0499999999997,733.8900000000001,724.04,18740.91999999994,6229.480000000004,2848.2299999999996,7116.47,723.38,6546.580000000007,13117.009999999993,680.9900000000002,477.30000000000007,3281.6300000000015,5590.8600000000015,2327.130000000001,4495.27,1298.6599999999999,334.92999999999995,5417.9299999999985,460.4000000000001,263.21,416.79,1139.3500000000008,1043.1,403.7,4206.2699999999995,2089.68,3723.87,-1126.0,114.00000000000003,-4.5,73.50000000000003,1258.06,398.27000000000004,176.5,982.57,138.03000000000006,586.7900000000001,1017.6800000000002,383.7,1312.06,2464.8899999999994,2056.8899999999994,340.84,2582.5099999999998,599.6800000000001,192.72000000000003,1745.5700000000006,4485.719999999999,1316.6600000000005,348.71000000000004,1922.2800000000009,1623.6299999999994,125.22,349.83,1089.18,716.3500000000001,4106.820000000003,363.95,3852.4999999999986,13309.039999999992,981.1800000000002,355.7,1000.3899999999999,1141.5,207.8,95.19999999999999,964.8299999999994,168.0,437.81999999999994,3652.2500000000014,603.7099999999997,11990.96,2.6645352591003757e-14,536.2099999999999,2101.3900000000003,238.85,3781.7400000000025,456.9000000000001,131.17,346.70000000000005,9114.939999999993,4064.989999999999,519.6099999999999,1004.7200000000003,160.54,218.45000000000002,1306.9799999999998,595.4000000000003,2753.3599999999988,410.71999999999997,415.7,197.70999999999998,511.3599999999999,7187.339999999993,1893.9500000000005,1982.809999999999,179.94,144.0,214.9,646.6800000000001,9861.380000000003,452.84999999999985,437.59999999999997,418.09999999999997,3320.2199999999984,618.27,3683.1300000000015,3002.679999999999,1032.5800000000006,2581.0400000000004,569.5600000000001,153.12000000000003,739 ...
